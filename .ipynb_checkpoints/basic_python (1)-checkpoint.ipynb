# %%
#basic syntax
#indentation
if True:
    print("pantech")
# Out:
# pantech

# %%
#comments
a=10
b=10
c=a+b
#print(c)

# %%
#multiline statement
a=10
b=10
c=10
d=a+\
b+\
c
print(d)
# Out:
# 30

# %%
#quatation
name='pantech'
mission="help to learn tecg knowledge"
mission1="""10 million to learn the tech knowlegde by the easier way 
any time 
any where 
any place"""
print(mission1)
# Out:
# 10 million to learn the tech knowlegde by the easier way
# any time
# any where
# any place

# %%
#variable
#create variable
company='pantechelearning'
number=100
is_patient=True

# %%
#multiple assignment
a=b=c=10
#print(c)

a,b,c,d=1,"philip",["alam","apple","vijay"],10.5
print(c)
print(type(c))
# Out:
# ['alam', 'apple', 'vijay']
# <class 'list'>

# %%
#casting 
a=str(10.5)
print(type(a))
# Out:
# <class 'str'>

# %%
#std
name="philip"
percentage=74
bio=["philip","BE",26,"single"]
bio2={"name":"philip"}

# %%
#data types
#numeric
a=10
b=20.5
c=1+2j
print(type(b))
# Out:
# <class 'float'>

# %%
#sequence
#string
name="philip"
print(name[0])
print(name.upper())
print(name.lower())
print(name.capitalize())
name[0]="T"
print(name)
# Out:
# p
# PHILIP
# philip
# Philip
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17760\3325222933.py in <module>
#       6 print(name.lower())
#       7 print(name.capitalize())
# ----> 8 name[0]="T"
#       9 print(name)
#
# TypeError: 'str' object does not support item assignment

# %%
#list
profile=["philip",26,"BE","pantech","pantech"]
profile[0]="bedit"
print(profile)
# Out:
# ['bedit', 26, 'BE', 'pantech', 'pantech']

# %%
#Tuple
profile=("philip",26,"BE","pantech","pantech")
#profile[0]="james"
print(profile)
# Out:
# ('philip', 26, 'BE', 'pantech', 'pantech')

# %%
#dict
bio={"name":"philip","age":26,"company":"pantech","role":"project Engineer","role":"project Engineer"}
bio["name"]="james"
print(bio)
# Out:
# {'name': 'james', 'age': 26, 'company': 'pantech', 'role': 'project Engineer'}

# %%
#boolen
is_new_patient=True
Have_good_credit=False

# %%
#conditional statement

if 10>15:
    print("pantech")

# %%
#if else

number =int(input("enter the number: "))

if number>0:
    print("positive number")
else:
    print("negative number")
# Out:
# enter the number: -5
# negative number

# %%
#if elif else
number =int(input("enter the number: "))
if number>0:
    print("positive number")
elif number==0:
    print("itz zero")
else:
    print("negative number")
# Out:
# enter the number: 0
# itz zero

# %%
climate=input("enter climate: ")
if climate=="hot":
    print("drink more water")
elif climate=="cool":
    print("wear warm cloths")
elif climate=="rainy":
    print("dont go outside note")
else:
    print("enjoy the climate ")
    print("Thank you")
# Out:
# enter climate: rainy
# dont go outside note

# %%
name="philip"
voter_age=int(input("voter_age: "))
voter_id=input("have_voter_id: ")
if voter_age>=18:
    print(f'{name} is eligible for voting')
    if voter_id=="yes":
        print(f'{name} can vote')
    else:
        print("apply voter id")
else:
    print(f'{name} not eligible for votig')
    print("voting age 18 and above")
# Out:
# voter_age: 27
# have_voter_id: no
# philip is eligible for voting
# apply voter id

# %%
#looping statement
#for loop
for i in range(10):
    if i==2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#while
i=1
while i<6:
    print(i)
    if i==4:
        break
    i+=1
# Out:
# 1
# 2
# 3
# 4

# %%
#function:
def profile(name,age):
    print(name)
    print(age)
#profile("philip",26)

# %%
def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):
    print(a*b)
add(2,4)
sub(100,50)
mul(4,4)
# Out:
# 6
# 50
# 16

# %%
def addeven(x,y):
    if x%2==0 and y%2==0:
        print(x+y)
    else:
        print(x*y)
addeven(3,10)
# Out:
# 30

# %%
def square(num):
    return num*num
square(9)
# Out:
# 81
