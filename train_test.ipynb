# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
music = pd.read_csv('archive/music.csv')
music.head()
# Out:
#    Age Gender      Genre
# 0   35   Male       Rock
# 1   56   Male        Pop
# 2   49   Male       Rock
# 3   52   Male  Classical
# 4   28   Male        Pop

# %%
music.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     50 non-null     int64
#  1   Gender  50 non-null     str
#  2   Genre   50 non-null     str
# dtypes: int64(1), str(2)
# memory usage: 1.3 KB

# %%
label_encode = LabelEncoder()

# %%
labels = label_encode.fit_transform(music['Gender'])

# %%
music['Gender'] = labels

# %%
x = music.drop(columns=['Genre'])
y = music['Genre']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state = 42)

# %%
print(x)
print(y)
# Out:
#     Age  Gender
# 0    35       1
# 1    56       1
# 2    49       1
# 3    52       1
# 4    28       1
# 5    42       0
# 6    30       1
# 7    42       1
# 8    22       1
# 9    55       1
# 10   52       0
# 11   29       1
# 12   23       0
# 13   24       1
# 14   34       1
# 15   52       1
# 16   21       1
# 17   18       1
# 18   58       0
# 19   44       0
# 20   34       1
# 21   59       1
# 22   51       0
# 23   46       0
# 24   43       0
# 25   19       1
# 26   41       1
# 27   24       0
# 28   17       1
# 29   51       0
# 30   59       0
# 31   46       0
# 32   20       0
# 33   59       1
# 34   59       0
# 35   51       0
# 36   60       0
# 37   37       1
# 38   37       1
# 39   22       0
# 40   28       0
# 41   30       0
# 42   46       1
# 43   43       0
# 44   32       1
# 45   50       0
# 46   41       0
# 47   39       1
# 48   20       1
# 49   29       1
# 0          Rock
# 1           Pop
# 2          Rock
# 3     Classical
# 4           Pop
# 5           Pop
# 6     Classical
# 7     Classical
# 8     Classical
# 9     Classical
# 10          Pop
# 11    Classical
# 12         Rock
# 13    Classical
# 14          Pop
# 15         Rock
# 16    Classical
# 17         Rock
# 18         Rock
# 19         Rock
# 20          Pop
# 21          Pop
# 22    Classical
# 23    Classical
# 24    Classical
# 25    Classical
# 26         Rock
# 27         Rock
# 28    Classical
# 29         Rock
# 30    Classical
# 31          Pop
# 32         Rock
# 33          Pop
# 34    Classical
# 35         Rock
# 36    Classical
# 37         Rock
# 38    Classical
# 39          Pop
# 40          Pop
# 41         Rock
# 42          Pop
# 43    Classical
# 44         Rock
# 45    Classical
# 46    Classical
# 47          Pop
# 48          Pop
# 49          Pop
# Name: Genre, dtype: str

# %%
print(type(x_train))
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# <class 'pandas.DataFrame'>
# (35,)
# (15, 2)
# (15,)

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
prediction = model.predict(x_test)
score = accuracy_score(y_test, prediction)
print(score)
print(prediction)
# Out:
# 0.3333333333333333
# ['Rock' 'Classical' 'Classical' 'Rock' 'Classical' 'Classical' 'Classical'
#  'Classical' 'Classical' 'Classical' 'Rock' 'Pop' 'Classical' 'Classical'
#  'Rock']
